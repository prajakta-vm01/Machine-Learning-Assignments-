# %% [markdown]
# Import Required Libraries

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# Read Data From different formats

# %%
df = pd.read_csv("usa_housing_kaggle.csv")
df.head()
# Out:
#     Price  Bedrooms  Bathrooms  SquareFeet  YearBuilt  GarageSpaces  LotSize  \
# 0  221958         1        1.9        4827       1979             2     1.45
# 1  771155         2        2.0        1035       1987             2     1.75
# 2  231932         1        3.0        2769       1982             1     1.46
# 3  465838         3        3.3        2708       1907             3     1.62
# 4  359178         4        3.4        1175       1994             2     0.74
#
#    ZipCode  CrimeRate  SchoolRating
# 0    82240      48.60             5
# 1    74315      92.03             9
# 2    79249      52.08             3
# 3    80587      61.65             1
# 4    20756      15.66             4

# %% [markdown]
# Find Shape of Data

# %%
df.shape
# Out:
# (300, 10)

# %% [markdown]
# Find Missing Values

# %%
df.isna().sum()
# Out:
# Price           0
# Bedrooms        0
# Bathrooms       0
# SquareFeet      0
# YearBuilt       0
# GarageSpaces    0
# LotSize         0
# ZipCode         0
# CrimeRate       0
# SchoolRating    0
# dtype: int64

# %% [markdown]
# Find data type of each column

# %%
df.dtypes
# Out:
# Price             int64
# Bedrooms          int64
# Bathrooms       float64
# SquareFeet        int64
# YearBuilt         int64
# GarageSpaces      int64
# LotSize         float64
# ZipCode           int64
# CrimeRate       float64
# SchoolRating      int64
# dtype: object

# %% [markdown]
# Finding out Zero's

# %%
(df==0).sum()
# Out:
# Price            0
# Bedrooms         0
# Bathrooms        0
# SquareFeet       0
# YearBuilt        0
# GarageSpaces    72
# LotSize          0
# ZipCode          0
# CrimeRate        0
# SchoolRating     0
# dtype: int64

# %% [markdown]
# Indexing and selecting data, sort data,

# %%
df['Price'].head()
# Out:
# 0    221958
# 1    771155
# 2    231932
# 3    465838
# 4    359178
# Name: Price, dtype: int64

# %%
df.columns
# Out:
# Index(['Price', 'Bedrooms', 'Bathrooms', 'SquareFeet', 'YearBuilt',
#        'GarageSpaces', 'LotSize', 'ZipCode', 'CrimeRate', 'SchoolRating'],
#       dtype='object')

# %% [markdown]
# Describe attributes of data

# %%
df.describe()
# Out:
#                Price    Bedrooms   Bathrooms  SquareFeet    YearBuilt  \
# count     300.000000  300.000000  300.000000   300.00000   300.000000
# mean   522761.916667    2.966667    2.464000  3052.75000  1962.616667
# std    256922.348275    1.451175    0.886184  1194.97144    36.005431
# min    112666.000000    1.000000    1.000000   840.00000  1902.000000
# 25%    299936.500000    2.000000    1.700000  2053.50000  1931.750000
# 50%    505806.500000    3.000000    2.400000  3127.00000  1961.000000
# 75%    744603.750000    4.000000    3.200000  4081.00000  1994.000000
# max    999684.000000    5.000000    4.000000  4997.00000  2022.000000
#
#        GarageSpaces     LotSize       ZipCode   CrimeRate  SchoolRating
# count    300.000000  300.000000    300.000000  300.000000    300.000000
# mean       1.513333    1.062200  54324.770000   49.324033      5.096667
# std        1.116832    0.543896  24718.938552   28.833220      2.674165
# ...

# %% [markdown]
# Counting unique values of data

# %%
df.nunique()
# Out:
# Price           300
# Bedrooms          5
# Bathrooms        31
# SquareFeet      285
# YearBuilt       111
# GarageSpaces      4
# LotSize         154
# ZipCode         300
# CrimeRate       295
# SchoolRating      9
# dtype: int64

# %% [markdown]
# Read Dataframe

# %%
d=pd.DataFrame({
    'ID':[101, 102, 103 ,104, 105],
    'NAME': ['Prajakta', 'Rutika', 'Srushti' ,'Pooja', 'Bhoomi'],
    'AGE': [19, 19, 19, 19, 19],
    'GENDER':['Female', 'Female', 'Female', 'Female', 'Female'],
    'DEPT': ['CSE-AI', 'IT' ,'IT' ,'IT' ,'CSE-AI'],
    'MARKS': [93 ,92 ,90, 91, 92],
    'ATTENDANCE': [95 ,92, 91, 95 ,95],
    'INTERSHIP': ['Yes' ,'Yes' ,'Yes' ,'NO' ,'Yes']
})

# %%
print(d)
# Out:
#     ID      NAME  AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP
# 0  101  Prajakta   19  Female  CSE-AI     93          95       Yes
# 1  102    Rutika   19  Female      IT     92          92       Yes
# 2  103   Srushti   19  Female      IT     90          91       Yes
# 3  104     Pooja   19  Female      IT     91          95        NO
# 4  105    Bhoomi   19  Female  CSE-AI     92          95       Yes

# %% [markdown]
#      Viewing Data

# %%
d.head()
# Out:
#     ID      NAME  AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP
# 0  101  Prajakta   19  Female  CSE-AI     93          95       Yes
# 1  102    Rutika   19  Female      IT     92          92       Yes
# 2  103   Srushti   19  Female      IT     90          91       Yes
# 3  104     Pooja   19  Female      IT     91          95        NO
# 4  105    Bhoomi   19  Female  CSE-AI     92          95       Yes

# %%
d.tail(3)
# Out:
#     ID     NAME  AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP
# 2  103  Srushti   19  Female      IT     90          91       Yes
# 3  104    Pooja   19  Female      IT     91          95        NO
# 4  105   Bhoomi   19  Female  CSE-AI     92          95       Yes

# %%
d.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
d.columns
# Out:
# Index(['ID', 'NAME', 'AGE', 'GENDER', 'DEPT', 'MARKS', 'ATTENDANCE',
#        'INTERSHIP'],
#       dtype='object')

# %%
d.to_numpy()
# Out:
# array([[101, 'Prajakta', 19, 'Female', 'CSE-AI', 93, 95, 'Yes'],
#        [102, 'Rutika', 19, 'Female', 'IT', 92, 92, 'Yes'],
#        [103, 'Srushti', 19, 'Female', 'IT', 90, 91, 'Yes'],
#        [104, 'Pooja', 19, 'Female', 'IT', 91, 95, 'NO'],
#        [105, 'Bhoomi', 19, 'Female', 'CSE-AI', 92, 95, 'Yes']],
#       dtype=object)

# %%
d.dtypes
# Out:
# ID             int64
# NAME          object
# AGE            int64
# GENDER        object
# DEPT          object
# MARKS          int64
# ATTENDANCE     int64
# INTERSHIP     object
# dtype: object

# %%
d.describe()
# Out:
#                ID   AGE      MARKS  ATTENDANCE
# count    5.000000   5.0   5.000000    5.000000
# mean   103.000000  19.0  91.600000   93.600000
# std      1.581139   0.0   1.140175    1.949359
# min    101.000000  19.0  90.000000   91.000000
# 25%    102.000000  19.0  91.000000   92.000000
# 50%    103.000000  19.0  92.000000   95.000000
# 75%    104.000000  19.0  92.000000   95.000000
# max    105.000000  19.0  93.000000   95.000000

# %%
d.sort_index(axis=1, ascending=False)
# Out:
#        NAME  MARKS INTERSHIP   ID  GENDER    DEPT  ATTENDANCE  AGE
# 0  Prajakta     93       Yes  101  Female  CSE-AI          95   19
# 1    Rutika     92       Yes  102  Female      IT          92   19
# 2   Srushti     90       Yes  103  Female      IT          91   19
# 3     Pooja     91        NO  104  Female      IT          95   19
# 4    Bhoomi     92       Yes  105  Female  CSE-AI          95   19

# %%
d.sort_values(by="MARKS", ascending=False)
# Out:
#     ID      NAME  AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP
# 0  101  Prajakta   19  Female  CSE-AI     93          95       Yes
# 1  102    Rutika   19  Female      IT     92          92       Yes
# 4  105    Bhoomi   19  Female  CSE-AI     92          95       Yes
# 3  104     Pooja   19  Female      IT     91          95        NO
# 2  103   Srushti   19  Female      IT     90          91       Yes

# %% [markdown]
# Selection

# %% [markdown]
#   Getitem[]

# %%
d["MARKS"]
# Out:
# 0    93
# 1    92
# 2    90
# 3    91
# 4    92
# Name: MARKS, dtype: int64

# %%
d[["NAME", "MARKS"]]
# Out:
#        NAME  MARKS
# 0  Prajakta     93
# 1    Rutika     92
# 2   Srushti     90
# 3     Pooja     91
# 4    Bhoomi     92

# %%
d[0:3]
# Out:
#     ID      NAME  AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP
# 0  101  Prajakta   19  Female  CSE-AI     93          95       Yes
# 1  102    Rutika   19  Female      IT     92          92       Yes
# 2  103   Srushti   19  Female      IT     90          91       Yes

# %% [markdown]
#       Selection by Lable

# %%
d.loc[:, ["NAME", "MARKS"]]
# Out:
#        NAME  MARKS
# 0  Prajakta     93
# 1    Rutika     92
# 2   Srushti     90
# 3     Pooja     91
# 4    Bhoomi     92

# %%
d.loc[0, "NAME"]
# Out:
# 'Prajakta'

# %%
d.at[0, "MARKS"]
# Out:
# np.int64(93)

# %% [markdown]
# Selection by position -- iloc[]

# %%
d.iloc[3]
# Out:
# ID               104
# NAME           Pooja
# AGE               19
# GENDER        Female
# DEPT              IT
# MARKS             91
# ATTENDANCE        95
# INTERSHIP         NO
# Name: 3, dtype: object

# %%
d.iloc[1:4, 0:3]
# Out:
#     ID     NAME  AGE
# 1  102   Rutika   19
# 2  103  Srushti   19
# 3  104    Pooja   19

# %%
d.iloc[[0,2,4],[1,5]]
# Out:
#        NAME  MARKS
# 0  Prajakta     93
# 2   Srushti     90
# 4    Bhoomi     92

# %% [markdown]
# Boolean Indexing

# %%
d[d["MARKS"]>91]
# Out:
#     ID      NAME  AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP
# 0  101  Prajakta   19  Female  CSE-AI     93          95       Yes
# 1  102    Rutika   19  Female      IT     92          92       Yes
# 4  105    Bhoomi   19  Female  CSE-AI     92          95       Yes

# %%
d[d["DEPT"].isin(["CSE-AI"])]
# Out:
#     ID      NAME  AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP
# 0  101  Prajakta   19  Female  CSE-AI     93          95       Yes
# 4  105    Bhoomi   19  Female  CSE-AI     92          95       Yes

# %% [markdown]
# Setting Values

# %%
d.at[0,"MARKS"]=95

# %%
d
# Out:
#     ID      NAME  AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP
# 0  101  Prajakta   19  Female  CSE-AI     95          95       Yes
# 1  102    Rutika   19  Female      IT     92          92       Yes
# 2  103   Srushti   19  Female      IT     90          91       Yes
# 3  104     Pooja   19  Female      IT     91          95        NO
# 4  105    Bhoomi   19  Female  CSE-AI     92          95       Yes

# %%
d.iat[1, 6] = 96

# %%
d
# Out:
#     ID      NAME  AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP
# 0  101  Prajakta   19  Female  CSE-AI     95          95       Yes
# 1  102    Rutika   19  Female      IT     92          96       Yes
# 2  103   Srushti   19  Female      IT     90          91       Yes
# 3  104     Pooja   19  Female      IT     91          95        NO
# 4  105    Bhoomi   19  Female  CSE-AI     92          95       Yes

# %%
s1=pd.Series([1,2,3,4,5])
d["GRADE"]=s1

# %%
d
# Out:
#     ID      NAME  AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP  GRADE
# 0  101  Prajakta   19  Female  CSE-AI     95          95       Yes      1
# 1  102    Rutika   19  Female      IT     92          96       Yes      2
# 2  103   Srushti   19  Female      IT     90          91       Yes      3
# 3  104     Pooja   19  Female      IT     91          95        NO      4
# 4  105    Bhoomi   19  Female  CSE-AI     92          95       Yes      5

# %% [markdown]
# Operations
# Stats(Mean)

# %%
d.mean(numeric_only=True)
# Out:
# ID            103.0
# AGE            19.0
# MARKS          91.6
# ATTENDANCE     93.6
# dtype: float64

# %%
d["MARKS"].mean()
# Out:
# np.float64(91.6)

# %% [markdown]
#  User defined functions

# %%
d[["MARKS", "ATTENDANCE"]].agg(lambda x: x.mean() * 2)
# Out:
# MARKS         183.2
# ATTENDANCE    187.2
# dtype: float64

# %%
d["MARKS"].transform(lambda x: x + 5)
# Out:
# 0    98
# 1    97
# 2    95
# 3    96
# 4    97
# Name: MARKS, dtype: int64

# %% [markdown]
# Value Counts

# %%
d["DEPT"].value_counts()
# Out:
# DEPT
# IT        3
# CSE-AI    2
# Name: count, dtype: int64

# %% [markdown]
# String Methods

# %%
d["NAME"].str.lower()
# Out:
# 0    prajakta
# 1      rutika
# 2     srushti
# 3       pooja
# 4      bhoomi
# Name: NAME, dtype: object

# %% [markdown]
# Merge
# Concat

# %%
result = pd.DataFrame({'RESULT':['Pass','Pass','Pass','Pass','Pass']})

# %%
pd.concat([d, result], axis=1)
# Out:
#     ID      NAME  AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP RESULT
# 0  101  Prajakta   19  Female  CSE-AI     93          95       Yes   Pass
# 1  102    Rutika   19  Female      IT     92          92       Yes   Pass
# 2  103   Srushti   19  Female      IT     90          91       Yes   Pass
# 3  104     Pooja   19  Female      IT     91          95        NO   Pass
# 4  105    Bhoomi   19  Female  CSE-AI     92          95       Yes   Pass

# %% [markdown]
# Join

# %%
dept = pd.DataFrame({
    'DEPT':['CSE-AI','IT'],
    'HOD':['Dr. Sharma','Dr. Patil']
})

# %%
pd.merge(d, dept, on='DEPT')
# Out:
#     ID      NAME  AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP         HOD
# 0  101  Prajakta   19  Female  CSE-AI     93          95       Yes  Dr. Sharma
# 1  102    Rutika   19  Female      IT     92          92       Yes   Dr. Patil
# 2  103   Srushti   19  Female      IT     90          91       Yes   Dr. Patil
# 3  104     Pooja   19  Female      IT     91          95        NO   Dr. Patil
# 4  105    Bhoomi   19  Female  CSE-AI     92          95       Yes  Dr. Sharma

# %%
d.sort_values(by='ATTENDANCE', ascending=True)
# Out:
#     ID      NAME  AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP
# 2  103   Srushti   19  Female      IT     90          91       Yes
# 1  102    Rutika   19  Female      IT     92          92       Yes
# 0  101  Prajakta   19  Female  CSE-AI     93          95       Yes
# 3  104     Pooja   19  Female      IT     91          95        NO
# 4  105    Bhoomi   19  Female  CSE-AI     92          95       Yes

# %%
d.isnull()
# Out:
#       ID   NAME    AGE  GENDER   DEPT  MARKS  ATTENDANCE  INTERSHIP
# 0  False  False  False   False  False  False       False      False
# 1  False  False  False   False  False  False       False      False
# 2  False  False  False   False  False  False       False      False
# 3  False  False  False   False  False  False       False      False
# 4  False  False  False   False  False  False       False      False

# %%
d.isna()
# Out:
#       ID   NAME    AGE  GENDER   DEPT  MARKS  ATTENDANCE  INTERSHIP
# 0  False  False  False   False  False  False       False      False
# 1  False  False  False   False  False  False       False      False
# 2  False  False  False   False  False  False       False      False
# 3  False  False  False   False  False  False       False      False
# 4  False  False  False   False  False  False       False      False

# %%
d.notna()
# Out:
#      ID  NAME   AGE  GENDER  DEPT  MARKS  ATTENDANCE  INTERSHIP
# 0  True  True  True    True  True   True        True       True
# 1  True  True  True    True  True   True        True       True
# 2  True  True  True    True  True   True        True       True
# 3  True  True  True    True  True   True        True       True
# 4  True  True  True    True  True   True        True       True

# %%
d.dropna()
# Out:
#     ID      NAME  AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP
# 0  101  Prajakta   19  Female  CSE-AI     93          95       Yes
# 1  102    Rutika   19  Female      IT     92          92       Yes
# 2  103   Srushti   19  Female      IT     90          91       Yes
# 3  104     Pooja   19  Female      IT     91          95        NO
# 4  105    Bhoomi   19  Female  CSE-AI     92          95       Yes

# %%
d.fillna(value=5)
# Out:
#     ID      NAME  AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP
# 0  101  Prajakta   19  Female  CSE-AI     93          95       Yes
# 1  102    Rutika   19  Female      IT     92          92       Yes
# 2  103   Srushti   19  Female      IT     90          91       Yes
# 3  104     Pooja   19  Female      IT     91          95        NO
# 4  105    Bhoomi   19  Female  CSE-AI     92          95       Yes

# %%
d.interpolate()
# Out:
# /tmp/ipython-input-3264332000.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   d.interpolate()
#     ID      NAME  AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP
# 0  101  Prajakta   19  Female  CSE-AI     93          95       Yes
# 1  102    Rutika   19  Female      IT     92          92       Yes
# 2  103   Srushti   19  Female      IT     90          91       Yes
# 3  104     Pooja   19  Female      IT     91          95        NO
# 4  105    Bhoomi   19  Female  CSE-AI     92          95       Yes

# %%
d.loc[len(d)] = [102, 'Rutika', 19, 'Female', 'IT', 92, 92, 'Yes']

# %%
d
# Out:
#     ID      NAME  AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP
# 0  101  Prajakta   19  Female  CSE-AI     93          95       Yes
# 1  102    Rutika   19  Female      IT     92          92       Yes
# 2  103   Srushti   19  Female      IT     90          91       Yes
# 3  104     Pooja   19  Female      IT     91          95        NO
# 4  105    Bhoomi   19  Female  CSE-AI     92          95       Yes
# 5  102    Rutika   19  Female      IT     92          92       Yes

# %%
d.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
d.drop_duplicates()
# Out:
#     ID      NAME  AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP
# 0  101  Prajakta   19  Female  CSE-AI     93          95       Yes
# 1  102    Rutika   19  Female      IT     92          92       Yes
# 2  103   Srushti   19  Female      IT     90          91       Yes
# 3  104     Pooja   19  Female      IT     91          95        NO
# 4  105    Bhoomi   19  Female  CSE-AI     92          95       Yes

# %%
d['AGE']=d['AGE'].astype(float)

# %%
print(d.dtypes)
# Out:
# ID              int64
# NAME           object
# AGE           float64
# GENDER         object
# DEPT           object
# MARKS           int64
# ATTENDANCE      int64
# INTERSHIP      object
# dtype: object

# %%
d.convert_dtypes
# Out:
# <bound method NDFrame.convert_dtypes of     ID      NAME   AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP
# 0  101  Prajakta  19.0  Female  CSE-AI     93          95       Yes
# 1  102    Rutika  19.0  Female      IT     92          92       Yes
# 2  103   Srushti  19.0  Female      IT     90          91       Yes
# 3  104     Pooja  19.0  Female      IT     91          95        NO
# 4  105    Bhoomi  19.0  Female  CSE-AI     92          95       Yes
# 5  102    Rutika  19.0  Female      IT     92          92       Yes>

# %%
d
# Out:
#     ID      NAME   AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP
# 0  101  Prajakta  19.0  Female  CSE-AI     93          95       Yes
# 1  102    Rutika  19.0  Female      IT     92          92       Yes
# 2  103   Srushti  19.0  Female      IT     90          91       Yes
# 3  104     Pooja  19.0  Female      IT     91          95        NO
# 4  105    Bhoomi  19.0  Female  CSE-AI     92          95       Yes
# 5  102    Rutika  19.0  Female      IT     92          92       Yes

# %%
d.shape
# Out:
# (5, 8)

# %%
(d==0).sum()
# Out:
# ID            0
# NAME          0
# AGE           0
# GENDER        0
# DEPT          0
# MARKS         0
# ATTENDANCE    0
# INTERSHIP     0
# dtype: int64

# %%
d.info
# Out:
# <bound method DataFrame.info of     ID      NAME  AGE  GENDER    DEPT  MARKS  ATTENDANCE INTERSHIP
# 0  101  Prajakta   19  Female  CSE-AI     93          95       Yes
# 1  102    Rutika   19  Female      IT     92          92       Yes
# 2  103   Srushti   19  Female      IT     90          91       Yes
# 3  104     Pooja   19  Female      IT     91          95        NO
# 4  105    Bhoomi   19  Female  CSE-AI     92          95       Yes>

# %%
d['DEPT'].nunique()
# Out:
# 2
